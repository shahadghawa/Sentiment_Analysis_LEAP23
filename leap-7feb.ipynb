# %% [markdown]
# ![](leap.PNG)

# %% [markdown]
# # Importing library

# %%
#libraries needed

# Data Processiong library
import pandas as pd
import snscrape.modules.twitter as sntwitter
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv 

#text processing & sentiment analysis
import nltk
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud, STOPWORDS
from emot.emo_unicode import UNICODE_EMOJI

porter = PorterStemmer()

lemmatizer = WordNetLemmatizer() 

import string
import re
import textblob
from textblob import TextBlob

from wordcloud import ImageColorGenerator
from PIL import Image

import warnings
# %matplotlib inline

# %%
#add new words to the list
new_stopwords = [ "https",
        "registered",
        "amp",
        "today",
        "Co",
        "Join",
        "today",
        "On",
        "S",
        "dr",
        "t",
        "signed"
        "pass",
        "just",
        "that",
        "ps",
        "meet"]
stopwrd = nltk.corpus.stopwords.words('english')
stopwrd.extend(new_stopwords)
stopwrd
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'https',
#  'registered',
#  'amp',
#  'today',
#  'Co',
#  'Join',
#  'today',
#  'On',
#  'S',
#  'dr',
#  't',
#  'signedpass',
#  'just',
#  'that',
#  'ps',
#  'meet']

# %% [markdown]
# # Loding dataset and explore it

# %%
#read the dataset
leap=pd.read_csv('leap7fep.csv')
leap
# Out:
#                        id      conversation_id               created_at  \
# 0     1623094515706765315  1623094515706765315  2023-02-07 23:01:02 UTC
# 1     1623094229042966528  1623094229042966528  2023-02-07 22:59:54 UTC
# 2     1623092766765989888  1623092766765989888  2023-02-07 22:54:05 UTC
# 3     1623092656111857675  1623092656111857675  2023-02-07 22:53:39 UTC
# 4     1623092075334860800  1623092075334860800  2023-02-07 22:51:21 UTC
# ...                   ...                  ...                      ...
# 2009  1622949570723344385  1622949570723344385  2023-02-07 13:25:05 UTC
# 2010  1622949463491854336  1622949463491854336  2023-02-07 13:24:39 UTC
# 2011  1622949415081082880  1622949415081082880  2023-02-07 13:24:28 UTC
# 2012  1622949378884349952  1622949378884349952  2023-02-07 13:24:19 UTC
# 2013  1622949370583826432  1622949370583826432  2023-02-07 13:24:17 UTC
#
#             date      time  timezone              user_id         username  \
# 0     2023-02-07  23:01:02         0   921114418385059840      hoomanminai
# 1     2023-02-07  22:59:54         0            473129911   samah_malibari
# 2     2023-02-07  22:54:05         0  1619752257775452161       saraalamah
# 3     2023-02-07  22:53:39         0             83387532    talal_almshan
# 4     2023-02-07  22:51:21         0            104062311  amal_mohammed90
# ...          ...       ...       ...                  ...              ...
# 2009  2023-02-07  13:25:05         0           1062031250      phnambagley
# 2010  2023-02-07  13:24:39         0            404888541        mtzsafwat
# 2011  2023-02-07  13:24:28         0  1042734080696217600        leansaudi
# 2012  2023-02-07  13:24:19         0            626041850       almaha1117
# 2013  2023-02-07  13:24:17         0  1200354104171737088         uflow123
#
#                       name place  ... geo source user_rt_id user_rt  \
# 0             Hooman Minai   NaN  ... NaN    NaN        NaN     NaN
# 1         Samah 🖥 Malibari   NaN  ... NaN    NaN        NaN     NaN
# 2          Sara Abu Alamah   NaN  ... NaN    NaN        NaN     NaN
# 3             طلال المشعان   NaN  ... NaN    NaN        NaN     NaN
# 4                     AMAL   NaN  ... NaN    NaN        NaN     NaN
# ...                    ...   ...  ...  ..    ...        ...     ...
# 2009          Phnam Bagley   NaN  ... NaN    NaN        NaN     NaN
# 2010      Moataz M. Safwat   NaN  ... NaN    NaN        NaN     NaN
# 2011            لين | Lean   NaN  ... NaN    NaN        NaN     NaN
# 2012  Maha A.AL-Qahtani 🇸🇦   NaN  ... NaN    NaN        NaN     NaN
# 2013       روان | aljouwan   NaN  ... NaN    NaN        NaN     NaN
#
#      retweet_id  reply_to  retweet_date  translate trans_src trans_dest
# 0           NaN        []           NaN        NaN       NaN        NaN
# 1           NaN        []           NaN        NaN       NaN        NaN
# 2           NaN        []           NaN        NaN       NaN        NaN
# 3           NaN        []           NaN        NaN       NaN        NaN
# 4           NaN        []           NaN        NaN       NaN        NaN
# ...         ...       ...           ...        ...       ...        ...
# 2009        NaN        []           NaN        NaN       NaN        NaN
# 2010        NaN        []           NaN        NaN       NaN        NaN
# 2011        NaN        []           NaN        NaN       NaN        NaN
# 2012        NaN        []           NaN        NaN       NaN        NaN
# 2013        NaN        []           NaN        NaN       NaN        NaN
#
# [2014 rows x 36 columns]

# %%
leap.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2014 entries, 0 to 2013
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               2014 non-null   int64
#  1   conversation_id  2014 non-null   int64
#  2   created_at       2014 non-null   object
#  3   date             2014 non-null   object
#  4   time             2014 non-null   object
#  5   timezone         2014 non-null   int64
#  6   user_id          2014 non-null   int64
#  7   username         2014 non-null   object
#  8   name             2014 non-null   object
#  9   place            2 non-null      object
#  10  tweet            2014 non-null   object
#  11  language         2014 non-null   object
#  12  mentions         2014 non-null   object
#  13  urls             2014 non-null   object
#  14  photos           2014 non-null   object
#  15  replies_count    2014 non-null   int64
#  16  retweets_count   2014 non-null   int64
#  17  likes_count      2014 non-null   int64
#  18  hashtags         2014 non-null   object
#  19  cashtags         2014 non-null   object
#  20  link             2014 non-null   object
#  21  retweet          2014 non-null   bool
#  22  quote_url        72 non-null     object
#  23  video            2014 non-null   int64
#  24  thumbnail        1406 non-null   object
#  25  near             0 non-null      float64
#  26  geo              0 non-null      float64
#  27  source           0 non-null      float64
#  28  user_rt_id       0 non-null      float64
#  29  user_rt          0 non-null      float64
#  30  retweet_id       0 non-null      float64
#  31  reply_to         2014 non-null   object
#  32  retweet_date     0 non-null      float64
#  33  translate        0 non-null      float64
#  34  trans_src        0 non-null      float64
#  35  trans_dest       0 non-null      float64
# dtypes: bool(1), float64(10), int64(8), object(17)
# memory usage: 552.8+ KB

# %%
#Shape of dataset
leap.shape
# Out:
# (2014, 36)

# %%
#The null value
leap.isna().sum()
# Out:
# id                    0
# conversation_id       0
# created_at            0
# date                  0
# time                  0
# timezone              0
# user_id               0
# username              0
# name                  0
# place              2012
# tweet                 0
# language              0
# mentions              0
# urls                  0
# photos                0
# replies_count         0
# retweets_count        0
# likes_count           0
# hashtags              0
# cashtags              0
# link                  0
# retweet               0
# quote_url          1942
# video                 0
# thumbnail           608
# near               2014
# geo                2014
# source             2014
# user_rt_id         2014
# user_rt            2014
# retweet_id         2014
# reply_to              0
# retweet_date       2014
# translate          2014
# trans_src          2014
# trans_dest         2014
# dtype: int64

# %%
#drop unnessury columne 
leap=leap.drop(['quote_url'], axis=1)
leap=leap.drop(["place"], axis=1)
leap=leap.drop(["near"], axis=1)
leap=leap.drop(["source"], axis=1)
leap=leap.drop(["geo"], axis=1)
leap=leap.drop(["user_rt_id"], axis=1)
leap=leap.drop(["user_rt"], axis=1)
leap=leap.drop(["retweet_id"], axis=1)
leap=leap.drop(["retweet_date"], axis=1)
leap=leap.drop(["translate"], axis=1)
leap=leap.drop(["trans_src"], axis=1)
leap=leap.drop(["trans_dest"], axis=1)
leap.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1623094515706765315  1623094515706765315  2023-02-07 23:01:02 UTC
# 1  1623094229042966528  1623094229042966528  2023-02-07 22:59:54 UTC
# 2  1623092766765989888  1623092766765989888  2023-02-07 22:54:05 UTC
# 3  1623092656111857675  1623092656111857675  2023-02-07 22:53:39 UTC
# 4  1623092075334860800  1623092075334860800  2023-02-07 22:51:21 UTC
#
#          date      time  timezone              user_id         username  \
# 0  2023-02-07  23:01:02         0   921114418385059840      hoomanminai
# 1  2023-02-07  22:59:54         0            473129911   samah_malibari
# 2  2023-02-07  22:54:05         0  1619752257775452161       saraalamah
# 3  2023-02-07  22:53:39         0             83387532    talal_almshan
# 4  2023-02-07  22:51:21         0            104062311  amal_mohammed90
#
#                name                                              tweet  ...  \
# 0      Hooman Minai  Just one more week until @Proofpoint joins 100...  ...
# 1  Samah 🖥 Malibari  تغطية اليوم كانت بعنوان "كم #روبوت شفت في #ليب...  ...
# 2   Sara Abu Alamah  زيارتي الاولى لمعرض #LEAP23 راح تكون غداً ان ش...  ...
# 3      طلال المشعان  #LEAP23 شيء عظيم للامانة وفخر ان المملكة هي ال...  ...
# 4              AMAL  النجاح الكبير لـ #مؤتمر_ليب23 بالنسخة الاولى خ...  ...
#
#   replies_count retweets_count likes_count  \
# 0             0              0           0
# 1             0              0           0
# 2             0              0           0
# 3             0              0           0
# 4             0              0           0
#
#                                             hashtags  cashtags  \
# 0                               ['leap23', 'riyadh']        []
# 1  ['روبوت', 'ليب23', 'robots', 'ليب', 'مؤتمر_ليب...        []
# 2                                         ['leap23']        []
# 3                          ['leap23', 'مؤتمر_ليب23']        []
# 4                          ['مؤتمر_ليب23', 'leap23']        []
#
#                                                 link  retweet video  \
# 0  https://twitter.com/HoomanMinai/status/1623094...    False     1
# 1  https://twitter.com/Samah_malibari/status/1623...    False     1
# 2  https://twitter.com/SaraAlamah/status/16230927...    False     0
# 3  https://twitter.com/talal_almshan/status/16230...    False     0
# 4  https://twitter.com/amal_mohammed90/status/162...    False     0
#
#                                            thumbnail reply_to
# 0    https://pbs.twimg.com/media/FoZj3G_X0AExfUN.jpg       []
# 1  https://pbs.twimg.com/ext_tw_video_thumb/16230...       []
# 2                                                NaN       []
# 3                                                NaN       []
# 4                                                NaN       []
#
# [5 rows x 24 columns]

# %%
#The null value
leap.isna().sum()
# Out:
# id                   0
# conversation_id      0
# created_at           0
# date                 0
# time                 0
# timezone             0
# user_id              0
# username             0
# name                 0
# tweet                0
# language             0
# mentions             0
# urls                 0
# photos               0
# replies_count        0
# retweets_count       0
# likes_count          0
# hashtags             0
# cashtags             0
# link                 0
# retweet              0
# video                0
# thumbnail          608
# reply_to             0
# dtype: int64

# %% [markdown]
# # Data Pre-processing

# %%
# Extract function for some of goals for leap event 
#since i am data analysis :)
def extract_data(n):
  n = str(n)
  resp = n.lower().find("data")
  if resp != -1 :
    return "data"
  else :
    return None 
#most of the project billed whit AI 
def extract_AI(n):
  n = str(n)
  resp = n.lower().find("ذكاء اصطناعي")
  if resp != -1 :
    return "ذكاء اصطناعي"
  else :
    return None 
#some of goals of leap
def extract_develop(n):
  n = str(n)
  resp = n.lower().find("تطور")
  if resp != -1 :
    return "تطور"
  else :
    return None 

def extract_future(n):
  n = str(n)
  resp = n.lower().find("المستقبل")
  if resp != -1 :
    return "المستقبل"
  else :
    return None 

def extract_fintech(n):
  n = str(n)
  resp = n.lower().find("فنتك")
  if resp != -1 :
    return "فنتك"
  else :
    return None 

def extract_Rhiadh(n):
   n = str(n)
   resp = n.lower().find("عاصمة التقنية")
   if resp != -1 :
    return "عاصمة التقنية"
   else :
    return None 


def extract_Outlook(n):
  n = str(n)
  resp = n.lower().find("افاق جديدة")
  if resp != -1 :
    return "آفاق جديدة"
  else :
    return None 

def extract_invesment(n):
  n = str(n)
  resp = n .lower().find("استثمار")
  if resp != -1 :
    return "استثمار"
  else :
    return None 
    
def extract_invesments(n):
  n = str(n)
  resp = n .lower().find("استثمارات")
  if resp != -1 :
    return "استثمارات"
  else :
    return None

# %%
#apply the functions on the tweets
leap['Data']=leap['tweet'].apply(extract_data)
leap['ذكاء اصطناعي']=leap['tweet'].apply(extract_AI)
leap['تطور']=leap['tweet'].apply(extract_develop)
leap['المستقبل']=leap['tweet'].apply(extract_future)
leap['فنتك']=leap['tweet'].apply(extract_fintech)
leap['عاصمة التقنية']=leap['tweet'].apply(extract_Rhiadh)
leap['آفاق جديدة']=leap['tweet'].apply(extract_Outlook)
leap['استثمار']=leap['tweet'].apply(extract_invesment)
leap['استثمارات']=leap['tweet'].apply(extract_invesments)

# %%
leap.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1623094515706765315  1623094515706765315  2023-02-07 23:01:02 UTC
# 1  1623094229042966528  1623094229042966528  2023-02-07 22:59:54 UTC
# 2  1623092766765989888  1623092766765989888  2023-02-07 22:54:05 UTC
# 3  1623092656111857675  1623092656111857675  2023-02-07 22:53:39 UTC
# 4  1623092075334860800  1623092075334860800  2023-02-07 22:51:21 UTC
#
#          date      time  timezone              user_id         username  \
# 0  2023-02-07  23:01:02         0   921114418385059840      hoomanminai
# 1  2023-02-07  22:59:54         0            473129911   samah_malibari
# 2  2023-02-07  22:54:05         0  1619752257775452161       saraalamah
# 3  2023-02-07  22:53:39         0             83387532    talal_almshan
# 4  2023-02-07  22:51:21         0            104062311  amal_mohammed90
#
#                name                                              tweet  ...  \
# 0      Hooman Minai  Just one more week until @Proofpoint joins 100...  ...
# 1  Samah 🖥 Malibari  تغطية اليوم كانت بعنوان "كم #روبوت شفت في #ليب...  ...
# 2   Sara Abu Alamah  زيارتي الاولى لمعرض #LEAP23 راح تكون غداً ان ش...  ...
# 3      طلال المشعان  #LEAP23 شيء عظيم للامانة وفخر ان المملكة هي ال...  ...
# 4              AMAL  النجاح الكبير لـ #مؤتمر_ليب23 بالنسخة الاولى خ...  ...
#
#   reply_to  Data ذكاء اصطناعي  تطور  المستقبل  فنتك  عاصمة التقنية آفاق جديدة  \
# 0       []  None         None  None      None  None           None       None
# 1       []  None         None  None      None  None           None       None
# 2       []  None         None  None      None  None           None       None
# 3       []  None         None  None      None  None           None       None
# 4       []  None         None  None      None  None           None       None
#
#   استثمار استثمارات
# 0    None      None
# 1    None      None
# 2    None      None
# 3    None      None
# 4    None      None
#
# [5 rows x 33 columns]

# %% [markdown]
# # Data processing

# %%
emoji = list (UNICODE_EMOJI.keys())

# %%
#function for preprocessing tweet in prepartion for sentiment analysis
def processedTweets(text):
    #change tweet to small letters 
    text = text.lower()
    #Removing @ and link 
    text = ''.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) |(\w+:\/\/\S+)"," ",text).split())
    #Removing repeating characters 
    text = re.sub(r'\@\w+|\#\w+|\d+','',text)
    #Removing punctuation and numbers 
    punct=str.maketrans('','',string.punctuation+string.digits)
    text=text.translate(punct)
    #tokenizing word and removing stop word from the tweet text
    tokens=word_tokenize(text)
    filtered_words=[w for w in tokens if w not in stopwrd]
    filtered_words=[w for w in filtered_words if w not in emoji]
    #lemmetizing words
    lemmatizer = WordNetLemmatizer()
    lemma_words = [lemmatizer.lemmatize(w)for w in filtered_words]
    text = " ".join(lemma_words)
    return text 

#For arabic processing tweet 

def normalizeArabic(text):
    text = re.sub("[إأٱآا]", "ا", text)
    text = re.sub("ى", "ي", text)
    return(text)

def deNoise(text):
    noise = re.compile(""" ّ    | 
                             َ    | 
                             ً    | 
                             ُ    | 
                             ٌ    | 
                             ِ    | 
                             ٍ    | 
                             ْ    | 
                             ـ     
                         """, re.VERBOSE)
    text = re.sub(noise, '', text)
    return text

# %%
#apply the functions on the tweets
leap['Processed_Tweets']=leap['tweet'].apply(processedTweets)
leap['Processed_Tweets']=leap['tweet'].apply(normalizeArabic)
leap['Processed_Tweets']=leap['tweet'].apply(deNoise)

# %%
leap.head()
# Out:
#                     id      conversation_id               created_at  \
# 0  1623094515706765315  1623094515706765315  2023-02-07 23:01:02 UTC
# 1  1623094229042966528  1623094229042966528  2023-02-07 22:59:54 UTC
# 2  1623092766765989888  1623092766765989888  2023-02-07 22:54:05 UTC
# 3  1623092656111857675  1623092656111857675  2023-02-07 22:53:39 UTC
# 4  1623092075334860800  1623092075334860800  2023-02-07 22:51:21 UTC
#
#          date      time  timezone              user_id         username  \
# 0  2023-02-07  23:01:02         0   921114418385059840      hoomanminai
# 1  2023-02-07  22:59:54         0            473129911   samah_malibari
# 2  2023-02-07  22:54:05         0  1619752257775452161       saraalamah
# 3  2023-02-07  22:53:39         0             83387532    talal_almshan
# 4  2023-02-07  22:51:21         0            104062311  amal_mohammed90
#
#                name                                              tweet  ...  \
# 0      Hooman Minai  Just one more week until @Proofpoint joins 100...  ...
# 1  Samah 🖥 Malibari  تغطية اليوم كانت بعنوان "كم #روبوت شفت في #ليب...  ...
# 2   Sara Abu Alamah  زيارتي الاولى لمعرض #LEAP23 راح تكون غداً ان ش...  ...
# 3      طلال المشعان  #LEAP23 شيء عظيم للامانة وفخر ان المملكة هي ال...  ...
# 4              AMAL  النجاح الكبير لـ #مؤتمر_ليب23 بالنسخة الاولى خ...  ...
#
#    Data ذكاء اصطناعي  تطور المستقبل  فنتك  عاصمة التقنية  آفاق جديدة استثمار  \
# 0  None         None  None     None  None           None        None    None
# 1  None         None  None     None  None           None        None    None
# 2  None         None  None     None  None           None        None    None
# 3  None         None  None     None  None           None        None    None
# 4  None         None  None     None  None           None        None    None
#
#   استثمارات                                   Processed_Tweets
# 0      None  Just one more week until @Proofpoint joins 100...
# 1      None  تغطية اليوم كانت بعنوان "كم #روبوت شفت في #ليب...
# 2      None  زيارتي الاولى لمعرض #LEAP23 راح تكون غدا ان شا...
# 3      None  #LEAP23 شيء عظيم للامانة وفخر ان المملكة هي ال...
# 4      None  النجاح الكبير ل #مؤتمر_ليب23 بالنسخة الاولى خل...
#
# [5 rows x 34 columns]

# %%
#word cloud 
plt.figure(figsize = (16,16))
wc = WordCloud(max_words = 500 , width = 1600 , height = 800,
               collocations=False).generate(" ".join(leap["Processed_Tweets"]))
plt.imshow(wc)

# %% [markdown]
# # Sentiment Analysis

# %%
# Function for polarity score
def polarity(Processed_Tweets):
    return TextBlob(Processed_Tweets).sentiment.polarity

# Function to get sentiment type
#setting the conditions
def sentimenttextblob(polarity):
    if polarity < 0:
        return "Negative"
    elif polarity == 0:
        return "Neutral"
    else:
        return "Positive"

# %%
# using the functions to get the polarity and sentiment
leap['Polarity'] = leap['Processed_Tweets'].apply(polarity)
leap['Sentiment'] = leap['Polarity'].apply(sentimenttextblob)

# %%
# plotting bar chart for the Sentiment
plt.subplot(1,2,1)
sent = leap['Sentiment'].value_counts()
sent.plot(kind='bar', color=['aqua'], figsize=(15,5))
plt.title('Sentiment percieved for #leap23 _feb 7', fontsize=16)
plt.xlabel('Types of sentiment')
plt.ylabel('Number of sentiment');

# %%
#save the csv file 
leap.to_csv("fep7_sentiment.csv")
